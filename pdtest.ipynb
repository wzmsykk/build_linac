# %%
import pandas as pd

# %%
pd.DataFrame({1,2,3,4,5,6,7,8})
df= pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df.head(1)['A'][0]
# Out:
# 1

# %%
index=1
paramrecord=pd.DataFrame([[1,2,3]],index=[index],columns=["A", "B", "C"])
pfdrecord=pd.DataFrame([4], index=[index], columns=["D"])
sfo=pd.DataFrame([5], index=[0], columns=["E"])
sfo_indexed=sfo.set_index(pd.Index([index]))
record=pd.concat([paramrecord,sfo_indexed, pfdrecord], axis=1)
record['A'].values[0]
# Out:
# 1
